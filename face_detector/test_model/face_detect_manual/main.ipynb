# %%
import nbimporter
import cv2 as cv
import os
import pickle
import numpy as np

from features import generate_features
from Intergral import process_image_data
from cascade_detector import findFaces
from utils import load_face_images, load_nonface_images, generate_non_face_patches
from adaboost import train_adaboost

# %%
# generate_non_face_patches(input_folder="../data/test/non_face",
#                          output_folder="../data/non_face") #input_folder, output_folder, patch_size=24, patches_per_image=50

# %%
# import shutil
# import random

# source_dir = "../data/non_face"
# extra_dir = "../data/storage"

# # Tạo thư mục đích nếu chưa tồn tại
# os.makedirs(extra_dir, exist_ok=True)

# # Lấy danh sách tất cả file
# files = [f for f in os.listdir(source_dir) if os.path.isfile(os.path.join(source_dir, f))]

# random.shuffle(files)

# keep = set(files[:10000])

# # Duyệt qua file và di chuyển phần dư
# for f in files[10000:]:
#     src_path = os.path.join(source_dir, f)
#     dst_path = os.path.join(extra_dir, f)
#     shutil.move(src_path, dst_path)

# print("✅ Đã giữ lại 10,000 file, di chuyển phần còn lại sang:", extra_dir)

# %%
# Load dataset
pos_imgs = load_face_images("../data/face")  # thư mục ảnh có khuôn mặt
neg_imgs = load_nonface_images("../data/non_face")  # thư mục ảnh không có khuôn mặt
# Out:
# Loading ../data/face:   0%|          | 0/5000 [00:00<?, ?it/s]
# Loading ../data/non_face:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
features = generate_features(step=2) # Generate all features
# Out:
# [INFO] Loading cached features from './cache/features_cache.pkl'...

# %%
# with open("./cache/adaboost_stumps.pkl", "rb") as f:
#     classifiers = pickle.load(f)

# %%
trained_stumps = train_adaboost(pos_imgs, neg_imgs, features, 6000) # pos_imgs, neg_imgs, features, max_stumps
# Out:
# Preparing Integral Matrix .....
# Processing Positive Images:   0%|          | 0/5000 [00:00<?, ?it/s]
# Processing Negative Images:   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trained_stumps = train_adaboost(pos_imgs, neg_imgs, features, 6000) # pos_imgs, neg_imgs, features, max_stumps
#
# File E:\esp-idf\examples\get-started\book-esp32c3-iot-projects-main\device_firmware\pbl3\camera_example\face_detector\model_manual\adaboost.ipynb:15, in train_adaboost(pos_imgs, neg_imgs, features, max_stumps, cache_path)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "1ac1cdcf-8491-4879-bb36-c213d0119391",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import nbimporter\n",
#      12     "from weak_classifier import DecisionStump\n",
#      13     "from tqdm.notebook import tqdm\n",
#      14     "import os\n",
# ---> 15     "import pickle\n",
#      16     "\n",
#      17     "from features import eval_feature\n",
#      18     "from Intergral import process_image_data\n",
#      19     "\n",
#      20     "def adaboost_model(feature_values, labels, max_stumps):\n",
#      21     "    n_features, n_samples = feature_values.shape\n",
#      22     "    y = np.copy(labels)\n",
#      23     "    y[y == 0] = -1  # convert 0→-1 for AdaBoost math\n",
#      24     "\n",
#      25     "    # init weights\n",
#      26     "    pos = np.sum(y == 1)\n",
#      27     "    neg = np.sum(y == -1)\n",
#      28     "    w = np.zeros(n_samples)\n",
#      29     "    w[y == 1] = 1.0 / (2 * pos)\n",
#      30     "    w[y == -1] = 1.0 / (2 * neg)\n",
#      31     "    w /= w.sum()\n",
#      32     "\n",
#      33     "    classifiers = []\n",
#      34     "\n",
#      35     "    for t in tqdm(range(max_stumps), desc=\"Training maximun num_stumps\"):\n",
#      36     "        best = None\n",
#      37     "\n",
#      38     "        for f in tqdm(range(n_features), desc=f\"Training stumps (Stump {t+1})\", leave=False):\n",
#      39     "            vals = feature_values[f]\n",
#      40     "            order = np.argsort(vals)\n",
#      41     "            sorted_vals, sorted_y, sorted_w = vals[order], y[order], w[order]\n",
#      42     "\n",
#      43     "            S_pos = (sorted_w * (sorted_y == 1)).cumsum()\n",
#      44     "            S_neg = (sorted_w * (sorted_y == -1)).cumsum()\n",
#      45     "            T_pos, T_neg = S_pos[-1], S_neg[-1]\n",
#      46     "\n",
#      47     "            errors1 = S_pos + (T_neg - S_neg) # Error for decide that non-face on the left and face on the right\n",
#      48     "            errors2 = S_neg + (T_pos - S_pos) # Error for decide that face on the left and non-face on the right\n",
#      49     "            errs = np.minimum(errors1, errors2)\n",
#      50     "            min_idx = np.argmin(errs)\n",
#      51     "            err = errs[min_idx]\n",
#      52     "\n",
#      53     "            thr = sorted_vals[min_idx]\n",
#      54     "            pol = -1 if errors1[min_idx] < errors2[min_idx] else 1\n",
#      55     "            best = (f, thr, pol)\n",
#      56     "                \n",
#      57     "        aos = 0.5 * np.log((1 - err + 1e-10) / (err + 1e-10))\n",
#      58     "        f_idx, thr, pol = best\n",
#      59     "\n",
#      60     "        stump = DecisionStump(f_idx, thr, pol, aos)\n",
#      61     "        preds = stump.predict(feature_values[f_idx])\n",
#      62     "        w *= np.exp(-aos * y * preds)\n",
#      63     "        w /= w.sum()\n",
#      64     "\n",
#      65     "        classifiers.append(stump)\n",
#      66     "\n",
#      67     "    return classifiers"
#      68    ]
#      69   },
#      70   {
#      71    "cell_type": "code",
#      72    "execution_count": 2,
#      73    "id": "1f67df06-b837-4a0a-a684-2892fe9e6a62",
#      74    "metadata": {},
#      75    "outputs": [],
#      76    "source": [
#      77     "def train_adaboost(pos_imgs, neg_imgs, features, max_stumps, cache_path=\"./cache/adaboost_stumps.pkl\"):\n",
#      78     "    os.makedirs(os.path.dirname(cache_path), exist_ok=True)\n",
#      79     "\n",
#      80     "    if os.path.exists(cache_path):\n",
#      81     "        print(f\"[INFO] Loading trained AdaBoost from '{cache_path}' ...\")\n",
#      82     "        with open(cache_path, \"rb\") as f:\n",
#      83     "            classifiers = pickle.load(f)\n",
#      84     "        print(f\"[INFO] Loaded AdaBoost with {len(classifiers)} stumps.\")\n",
#      85     "        return classifiers\n",
#      86     "\n",
#      87     "    print(\"Preparing Integral Matrix .....\")\n",
#      88     "    pos_iis, pos_siis = zip(*[\n",
#      89     "        process_image_data(im) for im in tqdm(pos_imgs, desc=\"Processing Positive Images\")\n",
#      90     "    ])\n",
#      91     "    neg_iis, neg_siis = zip(*[\n",
#      92     "        process_image_data(im) for im in tqdm(neg_imgs, desc=\"Processing Negative Images\")\n",
#      93     "    ])\n",
#      94     "\n",
#      95     "    all_iis = pos_iis + neg_iis\n",
#      96     "    all_siis = pos_siis + neg_siis\n",
#      97     "    labels = np.hstack([np.ones(len(pos_iis)), np.zeros(len(neg_iis))])\n",
#      98     "\n",
#      99     "    indices = np.arange(len(all_iis))\n",
#     100     "    np.random.shuffle(indices)\n",
#     101     "    \n",
#     102     "    all_iis = [all_iis[i] for i in indices]\n",
#     103     "    all_siis = [all_siis[i] for i in indices]\n",
#     104     "    labels = labels[indices]\n",
#     105     "\n",
#     106     "    print(\"Computing Haar feature values .....\")\n",
#     107     "    fv = np.zeros((len(features), len(all_iis)), dtype=np.float32)\n",
#     108     "    for i, f in enumerate(tqdm(features, desc=\"Evaluating features\")):\n",
#     109     "        for j, (ii_j, sii_j) in enumerate(zip(all_iis, all_siis)):\n",
#     110     "            fv[i, j] = eval_feature(ii_j, sii_j, f)\n",
#     111     "\n",
#     112     "    print(f\"[INFO] Training AdaBoost with {len(features)} features and {len(all_iis)} samples ...\")\n",
#     113     "    classifiers = adaboost_model(fv, labels, max_stumps)\n",
#     114     "\n",
#     115     "    with open(cache_path, \"wb\") as f:\n",
#     116     "        pickle.dump(classifiers, f)\n",
#     117     "    print(f\"[INFO] AdaBoost model saved to '{cache_path}'\")\n",
#     118     "\n",
#     119     "    return classifiers"
#     120    ]
#     121   },
#     122   {
#     123    "cell_type": "code",
#     124    "execution_count": null,
#     125    "id": "8a17a739-f30f-427e-9c42-241861b32304",
#     126    "metadata": {},
#     127    "outputs": [],
#     128    "source": []
#     129   }
#     130  ],
#     131  "metadata": {
#     132   "kernelspec": {
#     133    "display_name": "Python 3 (ipykernel)",
#     134    "language": "python",
#     135    "name": "python3"
#     136   },
#     137   "language_info": {
#     138    "codemirror_mode": {
#     139     "name": "ipython",
#     140     "version": 3
#     141    },
#     142    "file_extension": ".py",
#     143    "mimetype": "text/x-python",
#     144    "name": "python",
#     145    "nbconvert_exporter": "python",
#     146    "pygments_lexer": "ipython3",
#     147    "version": "3.10.0"
#     148   }
#     149  },
#     150  "nbformat": 4,
#     151  "nbformat_minor": 5
#     152 }
#
# File E:\esp-idf\examples\get-started\book-esp32c3-iot-projects-main\device_firmware\pbl3\camera_example\face_detector\model_manual\adaboost.ipynb:16, in <listcomp>(.0)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "1ac1cdcf-8491-4879-bb36-c213d0119391",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import nbimporter\n",
#      12     "from weak_classifier import DecisionStump\n",
#      13     "from tqdm.notebook import tqdm\n",
#      14     "import os\n",
#      15     "import pickle\n",
# ---> 16     "\n",
#      17     "from features import eval_feature\n",
#      18     "from Intergral import process_image_data\n",
#      19     "\n",
#      20     "def adaboost_model(feature_values, labels, max_stumps):\n",
#      21     "    n_features, n_samples = feature_values.shape\n",
#      22     "    y = np.copy(labels)\n",
#      23     "    y[y == 0] = -1  # convert 0→-1 for AdaBoost math\n",
#      24     "\n",
#      25     "    # init weights\n",
#      26     "    pos = np.sum(y == 1)\n",
#      27     "    neg = np.sum(y == -1)\n",
#      28     "    w = np.zeros(n_samples)\n",
#      29     "    w[y == 1] = 1.0 / (2 * pos)\n",
#      30     "    w[y == -1] = 1.0 / (2 * neg)\n",
#      31     "    w /= w.sum()\n",
#      32     "\n",
#      33     "    classifiers = []\n",
#      34     "\n",
#      35     "    for t in tqdm(range(max_stumps), desc=\"Training maximun num_stumps\"):\n",
#      36     "        best = None\n",
#      37     "\n",
#      38     "        for f in tqdm(range(n_features), desc=f\"Training stumps (Stump {t+1})\", leave=False):\n",
#      39     "            vals = feature_values[f]\n",
#      40     "            order = np.argsort(vals)\n",
#      41     "            sorted_vals, sorted_y, sorted_w = vals[order], y[order], w[order]\n",
#      42     "\n",
#      43     "            S_pos = (sorted_w * (sorted_y == 1)).cumsum()\n",
#      44     "            S_neg = (sorted_w * (sorted_y == -1)).cumsum()\n",
#      45     "            T_pos, T_neg = S_pos[-1], S_neg[-1]\n",
#      46     "\n",
#      47     "            errors1 = S_pos + (T_neg - S_neg) # Error for decide that non-face on the left and face on the right\n",
#      48     "            errors2 = S_neg + (T_pos - S_pos) # Error for decide that face on the left and non-face on the right\n",
#      49     "            errs = np.minimum(errors1, errors2)\n",
#      50     "            min_idx = np.argmin(errs)\n",
#      51     "            err = errs[min_idx]\n",
#      52     "\n",
#      53     "            thr = sorted_vals[min_idx]\n",
#      54     "            pol = -1 if errors1[min_idx] < errors2[min_idx] else 1\n",
#      55     "            best = (f, thr, pol)\n",
#      56     "                \n",
#      57     "        aos = 0.5 * np.log((1 - err + 1e-10) / (err + 1e-10))\n",
#      58     "        f_idx, thr, pol = best\n",
#      59     "\n",
#      60     "        stump = DecisionStump(f_idx, thr, pol, aos)\n",
#      61     "        preds = stump.predict(feature_values[f_idx])\n",
#      62     "        w *= np.exp(-aos * y * preds)\n",
#      63     "        w /= w.sum()\n",
#      64     "\n",
#      65     "        classifiers.append(stump)\n",
#      66     "\n",
#      67     "    return classifiers"
#      68    ]
#      69   },
#      70   {
#      71    "cell_type": "code",
#      72    "execution_count": 2,
#      73    "id": "1f67df06-b837-4a0a-a684-2892fe9e6a62",
#      74    "metadata": {},
#      75    "outputs": [],
#      76    "source": [
#      77     "def train_adaboost(pos_imgs, neg_imgs, features, max_stumps, cache_path=\"./cache/adaboost_stumps.pkl\"):\n",
#      78     "    os.makedirs(os.path.dirname(cache_path), exist_ok=True)\n",
#      79     "\n",
#      80     "    if os.path.exists(cache_path):\n",
#      81     "        print(f\"[INFO] Loading trained AdaBoost from '{cache_path}' ...\")\n",
#      82     "        with open(cache_path, \"rb\") as f:\n",
#      83     "            classifiers = pickle.load(f)\n",
#      84     "        print(f\"[INFO] Loaded AdaBoost with {len(classifiers)} stumps.\")\n",
#      85     "        return classifiers\n",
#      86     "\n",
#      87     "    print(\"Preparing Integral Matrix .....\")\n",
#      88     "    pos_iis, pos_siis = zip(*[\n",
#      89     "        process_image_data(im) for im in tqdm(pos_imgs, desc=\"Processing Positive Images\")\n",
#      90     "    ])\n",
#      91     "    neg_iis, neg_siis = zip(*[\n",
#      92     "        process_image_data(im) for im in tqdm(neg_imgs, desc=\"Processing Negative Images\")\n",
#      93     "    ])\n",
#      94     "\n",
#      95     "    all_iis = pos_iis + neg_iis\n",
#      96     "    all_siis = pos_siis + neg_siis\n",
#      97     "    labels = np.hstack([np.ones(len(pos_iis)), np.zeros(len(neg_iis))])\n",
#      98     "\n",
#      99     "    indices = np.arange(len(all_iis))\n",
#     100     "    np.random.shuffle(indices)\n",
#     101     "    \n",
#     102     "    all_iis = [all_iis[i] for i in indices]\n",
#     103     "    all_siis = [all_siis[i] for i in indices]\n",
#     104     "    labels = labels[indices]\n",
#     105     "\n",
#     106     "    print(\"Computing Haar feature values .....\")\n",
#     107     "    fv = np.zeros((len(features), len(all_iis)), dtype=np.float32)\n",
#     108     "    for i, f in enumerate(tqdm(features, desc=\"Evaluating features\")):\n",
#     109     "        for j, (ii_j, sii_j) in enumerate(zip(all_iis, all_siis)):\n",
#     110     "            fv[i, j] = eval_feature(ii_j, sii_j, f)\n",
#     111     "\n",
#     112     "    print(f\"[INFO] Training AdaBoost with {len(features)} features and {len(all_iis)} samples ...\")\n",
#     113     "    classifiers = adaboost_model(fv, labels, max_stumps)\n",
#     114     "\n",
#     115     "    with open(cache_path, \"wb\") as f:\n",
#     116     "        pickle.dump(classifiers, f)\n",
#     117     "    print(f\"[INFO] AdaBoost model saved to '{cache_path}'\")\n",
#     118     "\n",
#     119     "    return classifiers"
#     120    ]
#     121   },
#     122   {
#     123    "cell_type": "code",
#     124    "execution_count": null,
#     125    "id": "8a17a739-f30f-427e-9c42-241861b32304",
#     126    "metadata": {},
#     127    "outputs": [],
#     128    "source": []
#     129   }
#     130  ],
#     131  "metadata": {
#     132   "kernelspec": {
#     133    "display_name": "Python 3 (ipykernel)",
#     134    "language": "python",
#     135    "name": "python3"
#     136   },
#     137   "language_info": {
#     138    "codemirror_mode": {
#     139     "name": "ipython",
#     140     "version": 3
#     141    },
#     142    "file_extension": ".py",
#     143    "mimetype": "text/x-python",
#     144    "name": "python",
#     145    "nbconvert_exporter": "python",
#     146    "pygments_lexer": "ipython3",
#     147    "version": "3.10.0"
#     148   }
#     149  },
#     150  "nbformat": 4,
#     151  "nbformat_minor": 5
#     152 }
#
# File E:\esp-idf\examples\get-started\book-esp32c3-iot-projects-main\device_firmware\pbl3\camera_example\face_detector\model_manual\Intergral.ipynb:5, in process_image_data(img)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": 4,
#       6    "id": "ef8910de-dba4-4cc8-9d31-b66e681f477e",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "\n",
#      12     "def process_image_data(img: np.ndarray):\n",
#      13     "    \n",
#      14     "    height, width = img.shape\n",
#      15     "    \n",
#      16     "    # Chuẩn hóa ảnh về [0,1]\n",
#      17     "    normalized = img.astype(np.float64) / 255.0\n",
#      18     "\n",
#      19     "    # Khởi tạo ma trận tích phân có padding 0\n",
#      20     "    integral_matrix = np.zeros((height + 1, width + 1), dtype=np.float64)\n",
#      21     "    squared_integral_matrix = np.zeros((height + 1, width + 1), dtype=np.float64)\n",
#      22     "\n",
#      23     "    # Tính integral và squared integral theo công thức tích lũy\n",
#      24     "    for y in range(height):\n",
#      25     "        for x in range(width):\n",
#      26     "            value = normalized[y, x]\n",
#      27     "            integral_matrix[y + 1, x + 1] = (\n",
#      28     "                value\n",
#      29     "                + integral_matrix[y, x + 1]\n",
#      30     "                + integral_matrix[y + 1, x]\n",
#      31     "                - integral_matrix[y, x]\n",
#      32     "            )\n",
#      33     "            squared_integral_matrix[y + 1, x + 1] = (\n",
#      34     "                value * value\n",
#      35     "                + squared_integral_matrix[y, x + 1]\n",
#      36     "                + squared_integral_matrix[y + 1, x]\n",
#      37     "                - squared_integral_matrix[y, x]\n",
#      38     "            )\n",
#      39     "\n",
#      40     "    return integral_matrix, squared_integral_matrix\n",
#      41     "\n",
#      42     "def rect_sum(matrix: np.ndarray, x:int, y:int, w:int, h:int): \n",
#      43     "    return matrix[y + h, x + w] - (matrix[y + h, x] if (x > 0) else 0) - (matrix[y, x + w] if (y > 0) else 0) + (matrix[y, x] if (x > 0 and y > 0) else 0)\n"
#      44    ]
#      45   },
#      46   {
#      47    "cell_type": "code",
#      48    "execution_count": null,
#      49    "id": "364272a9-20d9-40b9-b360-77afd074ea15",
#      50    "metadata": {},
#      51    "outputs": [],
#      52    "source": []
#      53   }
#      54  ],
#      55  "metadata": {
#      56   "kernelspec": {
#      57    "display_name": "Python 3 (ipykernel)",
#      58    "language": "python",
#      59    "name": "python3"
#      60   },
#      61   "language_info": {
#      62    "codemirror_mode": {
#      63     "name": "ipython",
#      64     "version": 3
#      65    },
#      66    "file_extension": ".py",
#      67    "mimetype": "text/x-python",
#      68    "name": "python",
#      69    "nbconvert_exporter": "python",
#      70    "pygments_lexer": "ipython3",
#      71    "version": "3.10.0"
#      72   }
#      73  },
#      74  "nbformat": 4,
#      75  "nbformat_minor": 5
#      76 }
#
# ValueError: too many values to unpack (expected 2)

# %%
width = 240
height = 135
test_img = cv.imread("./data/test/face/7.png", cv2.IMREAD_GRAYSCALE)
test_img = cv.resize(test_img, (width, height))
ii, sii = process_image_data(test_img)

results = findFaces(ii, sii, trained_stumps, width, height, 1.5, 5, 0.25) #integralImage, squaredIntegralImage, stumps, width, height, stepSize, maxScale, scaleStep
print(results)

# %%
# for i in range(5):
#     print(i, trained_stumps[i].threshold, trained_stumps[i].polarity, trained_stumps[i].amountOfSay)

# %%
# face_cascade_path = "./haarcascade_frontalface_alt.xml"

# # Tạo đối tượng cascade
# face_cascade = cv.CascadeClassifier(face_cascade_path)

# if face_cascade.empty():
#     print("--(!) Error loading face cascade")
#     exit(0)

# # Mở camera
# cap = cv.VideoCapture(0)
# if not cap.isOpened():
#     print("--(!) Error opening video capture")
#     exit(0)

# print("[INFO] Press ESC to exit.")

# while True:
#     ret, frame = cap.read()
#     if frame is None:
#         print("--(!) No captured frame -- Break!")
#         break

#     # Chuyển sang ảnh xám
#     gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
#     gray = cv.equalizeHist(gray)

#     # Phát hiện khuôn mặt
#     faces = face_cascade.detectMultiScale(gray)

#     # Vẽ khung quanh khuôn mặt
#     for (x, y, w, h) in faces:
#         center = (x + w // 2, y + h // 2)
#         frame = cv.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 255), 2)

#     # Hiển thị kết quả
#     cv.imshow('Face Detection', frame)

#     # Nhấn ESC để thoát
#     if cv.waitKey(10) == 27:
#         break

# cap.release()
# cv.destroyAllWindows()
