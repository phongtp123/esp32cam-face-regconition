# %%
from flask import Flask, render_template_string
import nbimporter
from backend import register_backend_routes

# %%
app = Flask(__name__)

# %%
html_template = """
<!doctype html>
<html>
<head>
  <title>ESP32-CAM Face Detection Stream</title>
  <style>
    body { font-family: Arial, sans-serif; text-align:center; margin-top:20px; }
    #video { border: 2px solid #444; max-width: 90%; height: auto; }
    .btn { padding: 8px 14px; margin: 8px; cursor: pointer; border-radius:6px; border:1px solid #666; background:#eee; }
  </style>
</head>
<body>
  <h2>ESP32-CAM — Face Detection (Server-side)</h2>
  <div>
    <button class="btn" onclick="startStream()">Start Stream</button>
    <button class="btn" onclick="stopStream()">Stop Stream</button>
  </div>
  <div>
    <img id="video" src="" alt="Stream will appear here">
  </div>

  <script>
    const video = document.getElementById('video');
    function startStream(){
      video.src = "/video_feed";
    }
    function stopStream(){
      video.src = "";
      fetch('/stop_capture').catch(()=>{});
    }
  </script>
</body>
</html>
"""

@app.route('/')
def index():
    return render_template_string(html_template)


# Đăng ký backend routes
register_backend_routes(app)

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=3001, threaded=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:3001
#  * Running on http://192.168.100.152:3001
# Press CTRL+C to quit
# 127.0.0.1 - - [26/Oct/2025 10:38:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Oct/2025 10:38:58] "GET /video_feed HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "E:\esp-idf\examples\get-started\book-esp32c3-iot-projects-main\device_firmware\pbl3\camera_example\venv\lib\site-packages\werkzeug\serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#   File "E:\esp-idf\examples\get-started\book-esp32c3-iot-projects-main\device_firmware\pbl3\camera_example\venv\lib\site-packages\werkzeug\serving.py", line 333, in execute
#     for data in application_iter:
#   File "E:\esp-idf\examples\get-started\book-esp32c3-iot-projects-main\device_firmware\pbl3\camera_example\venv\lib\site-packages\werkzeug\wsgi.py", line 256, in __next__
#     return self._next()
#   File "E:\esp-idf\examples\get-started\book-esp32c3-iot-projects-main\device_firmware\pbl3\camera_example\venv\lib\site-packages\werkzeug\wrappers\response.py", line 32, in _iter_encoded
#     for item in iterable:
#   File "backend.ipynb", line 3, in detect_frames
#     {
#   File "appUtils.ipynb", line 6, in get_video_capture
#     "id": "06efab3e-b42a-4c79-9420-c42067661be6",
# NameError: name 'cap_lock' is not defined
